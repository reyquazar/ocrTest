# %%
from ultralytics import YOLO

# %%
model = YOLO('yolo26n.pt')
data_path= 'data/icdar2013/TestImages/img_1.jpg'
# data_path = 'data/09.jpg'
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 model = YOLO('yolo26n.pt')
#       2 data_path= 'data/icdar2013/TestImages/img_1.jpg'
#       3 # data_path = 'data/09.jpg'
#
# File ~\AppData\Local\Python\pythoncore-3.10-64\lib\site-packages\ultralytics\models\yolo\model.py:76, in YOLO.__init__(self, model, task, verbose)
#      73     self.__dict__ = new_instance.__dict__
#      74 else:
#      75     # Continue with default YOLO initialization
# ---> 76     super().__init__(model=model, task=task, verbose=verbose)
#      77     if hasattr(self.model, "model") and "RTDETR" in self.model.model[-1]._get_name():  # if RTDETR head
#      78         from ultralytics import RTDETR
#
# File ~\AppData\Local\Python\pythoncore-3.10-64\lib\site-packages\ultralytics\engine\model.py:144, in Model.__init__(self, model, task, verbose)
# ...

# %%
results = model(data_path, show=True, save=True)
# Out:
# WARNING Environment does not support cv2.imshow() or PIL Image.show()
# OpenCV(4.13.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:1301: error: (-2:Unspecified error) The function is not implemented. Rebuild the library with Windows, GTK+ 2.x or Cocoa support. If you are on Ubuntu or Debian, install libgtk2.0-dev and pkg-config, then re-run cmake or configure script in function 'cvShowImage'
#
#
# image 1/1 H:\Coding\PyProjects\ocrTest\data\icdar2013\Challenge2_Test_Task12_Images\img_1.jpg: 640x480 (no detections), 45.0ms
# Speed: 1.3ms preprocess, 45.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to H:\Coding\PyProjects\ocrTest\runs\detect\predict3
